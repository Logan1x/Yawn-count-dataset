# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'column1':[34,54,32,23,26]})
df
# Out:
#    column1
# 0       34
# 1       54
# 2       32
# 3       23
# 4       26

# %%
df['date'] = pd.date_range(start='1/1/1979', periods=len(df), freq='D')

# %%
df
# Out:
#    column1       date
# 0       34 1979-01-01
# 1       54 1979-01-02
# 2       32 1979-01-03
# 3       23 1979-01-04
# 4       26 1979-01-05

# %%
df1 = np.random.randint(3,7, size=60)

# %%
df1
# Out:
# array([3, 6, 3, 5, 6, 6, 5, 3, 5, 4, 6, 5, 6, 4, 3, 5, 4, 5, 6, 5, 5, 5,
#        6, 6, 4, 6, 6, 4, 5, 3, 3, 5, 4, 4, 5, 4, 5, 5, 6, 5, 5, 3, 4, 5,
#        6, 6, 4, 6, 4, 4, 4, 3, 3, 4, 3, 3, 4, 5, 5, 5])

# %%
df['random'] = df1[:5]

# %%
df
# Out:
#    column1       date  random
# 0       34 1979-01-01       3
# 1       54 1979-01-02       6
# 2       32 1979-01-03       3
# 3       23 1979-01-04       5
# 4       26 1979-01-05       6

# %%
#df2 = pd.date_range(start='23/08/2020', periods=len(df), freq='W-TUE')

ix_mon = pd.date_range('23/08/2020', periods=60, freq='W-TUE')
ix_wed = pd.date_range('23/08/2020', periods=60, freq='W-FRI')
ix_mw = ix_mon.union(ix_wed)[:60]
ix_mw
# Out:
# DatetimeIndex(['2020-08-25', '2020-08-28', '2020-09-01', '2020-09-04',
#                '2020-09-08', '2020-09-11', '2020-09-15', '2020-09-18',
#                '2020-09-22', '2020-09-25', '2020-09-29', '2020-10-02',
#                '2020-10-06', '2020-10-09', '2020-10-13', '2020-10-16',
#                '2020-10-20', '2020-10-23', '2020-10-27', '2020-10-30',
#                '2020-11-03', '2020-11-06', '2020-11-10', '2020-11-13',
#                '2020-11-17', '2020-11-20', '2020-11-24', '2020-11-27',
#                '2020-12-01', '2020-12-04', '2020-12-08', '2020-12-11',
#                '2020-12-15', '2020-12-18', '2020-12-22', '2020-12-25',
#                '2020-12-29', '2021-01-01', '2021-01-05', '2021-01-08',
#                '2021-01-12', '2021-01-15', '2021-01-19', '2021-01-22',
#                '2021-01-26', '2021-01-29', '2021-02-02', '2021-02-05',
#                '2021-02-09', '2021-02-12', '2021-02-16', '2021-02-19',
# ...

# %%
df1 = pd.DataFrame({'Yawn_Count':np.random.randint(3,11, size=60)})

# %%
df1['Date'] = ix_mw

# %%
df1.head()
# Out:
#    Yawn_Count       Date
# 0           8 2020-08-25
# 1          10 2020-08-28
# 2           9 2020-09-01
# 3           9 2020-09-04
# 4           4 2020-09-08

# %%
features = ['Date','Yawn_Count']

# %%
df2 = df1[features]

# %%
df2
# Out:
#          Date  Yawn_Count
# 0  2020-08-25           8
# 1  2020-08-28          10
# 2  2020-09-01           9
# 3  2020-09-04           9
# 4  2020-09-08           4
# 5  2020-09-11           3
# 6  2020-09-15           6
# 7  2020-09-18          10
# 8  2020-09-22           7
# 9  2020-09-25           3
# 10 2020-09-29           9
# 11 2020-10-02           9
# 12 2020-10-06           6
# 13 2020-10-09           9
# 14 2020-10-13          10
# 15 2020-10-16          10
# 16 2020-10-20           9
# 17 2020-10-23           5
# 18 2020-10-27           4
# 19 2020-10-30           7
# 20 2020-11-03           9
# 21 2020-11-06           4
# 22 2020-11-10           8
# 23 2020-11-13           3
# 24 2020-11-17           8
# 25 2020-11-20           6
# 26 2020-11-24          10
# 27 2020-11-27           3
# 28 2020-12-01           5
# 29 2020-12-04           3
# 30 2020-12-08           7
# 31 2020-12-11           8
# 32 2020-12-15           9
# 33 2020-12-18           3
# ...

# %%
df2.to_csv(r'Yawn_count.csv',index = None)
